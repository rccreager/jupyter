# %% [markdown]
# ## Introduction to Seaborn
# 26 May 2016
# * [Example Notebook](https://www.kaggle.com/ranliu/wik-workshop-data-visualization-with-exercises)
# * [Seaborn Example](https://seaborn.pydata.org/index.html)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
import seaborn as sns

# %%
death = pd.read_csv("data/death_USA.csv",nrows=10000)

top5cause = death['Cause Name'].value_counts().index[range(0,5)]
print top5cause
top5 = death[death['Cause Name'].isin(top5cause)]
top5CA = top5[top5['State'].equals('California')]
top5.head()

#death.head()
# Out:
# Index([u'Essential hypertension and hypertensive renal disease', u'CLRD',
#        u'Homicide', u'Chronic liver disease and cirrhosis',
#        u'Influenza and pneumonia'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-d6f23ab6907e> in <module>()
#       4 print top5cause
#       5 top5 = death[death['Cause Name'].isin(top5cause)]
# ----> 6 top5CA = top5[top5['State'].equals('California')]
#       7 top5.head()
#       8
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2690         # get column
# ...

# %%
sns.violinplot(y='Cause Name', x='Deaths', data=top5)
